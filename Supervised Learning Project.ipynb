# %% [markdown]
# # PART-A

# %% [markdown]
# ### 1. Data Understanding:
# ### A. Read all the 3 CSV files as DataFrame and store them into 3 separate variables.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
d1=pd.read_csv('Downloads/Normal.csv') #reading the dataframe 1 and storing it in variable d1
d2=pd.read_csv('Downloads/Type_H.csv') #reading the dataframe 2 and storing it in variable d2
d3=pd.read_csv('Downloads/Type_S.csv') #reading the dataframe 3 and storing it in variable d3

# %%
d1 #dataframe 1 (normal.csv)
# Out:
#     P_incidence     P_tilt    L_angle    S_slope    P_radius  S_Degree   Class
# 0     38.505273  16.964297  35.112814  21.540976  127.632875  7.986683  Normal
# 1     54.920858  18.968430  51.601455  35.952428  125.846646  2.001642  Normal
# 2     44.362490   8.945435  46.902096  35.417055  129.220682  4.994195  Normal
# 3     48.318931  17.452121  48.000000  30.866809  128.980308 -0.910941  Normal
# 4     45.701789  10.659859  42.577846  35.041929  130.178314 -3.388910  Normal
# ..          ...        ...        ...        ...         ...       ...     ...
# 95    47.903565  13.616688  36.000000  34.286877  117.449062 -4.245395  Normal
# 96    53.936748  20.721496  29.220534  33.215251  114.365845 -0.421010  Normal
# 97    61.446597  22.694968  46.170347  38.751628  125.670725 -2.707880  Normal
# 98    45.252792   8.693157  41.583126  36.559635  118.545842  0.214750  Normal
# 99    33.841641   5.073991  36.641233  28.767649  123.945244 -0.199249  Normal
#
# [100 rows x 7 columns]

# %%
d2 #dataframe 2 (Type_H.csv)
# Out:
#     P_incidence     P_tilt    L_angle    S_slope    P_radius   S_Degree  \
# 0     63.027817  22.552586  39.609117  40.475232   98.672917  -0.254400
# 1     39.056951  10.060991  25.015378  28.995960  114.405425   4.564259
# 2     68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317
# 3     69.297008  24.652878  44.311238  44.644130  101.868495  11.211523
# 4     49.712859   9.652075  28.317406  40.060784  108.168725   7.918501
# 5     40.250200  13.921907  25.124950  26.328293  130.327871   2.230652
# 6     53.432928  15.864336  37.165934  37.568592  120.567523   5.988551
# 7     45.366754  10.755611  29.038349  34.611142  117.270067 -10.675871
# 8     43.790190  13.533753  42.690814  30.256437  125.002893  13.289018
# 9     36.686353   5.010884  41.948751  31.675469   84.241415   0.664437
# 10    49.706610  13.040974  31.334500  36.665635  108.648265  -7.825986
# 11    31.232387  17.715819  15.500000  13.516568  120.055399   0.499751
# ...

# %%
d3 #dataframe 3 (Type_S.csv)
# Out:
#      P_incidence     P_tilt    L_angle    S_slope    P_radius    S_Degree  \
# 0      74.377678  32.053104  78.772013  42.324573  143.560690   56.125906
# 1      89.680567  32.704435  83.130732  56.976132  129.955476   92.027277
# 2      44.529051   9.433234  52.000000  35.095817  134.711772   29.106575
# 3      77.690577  21.380645  64.429442  56.309932  114.818751   26.931841
# 4      76.147212  21.936186  82.961502  54.211027  123.932010   10.431972
# ..           ...        ...        ...        ...         ...         ...
# 145    80.111572  33.942432  85.101608  46.169139  125.593624  100.292107
# 146    95.480229  46.550053  59.000000  48.930176   96.683903   77.283072
# 147    74.094731  18.823727  76.032156  55.271004  128.405731   73.388216
# 148    87.679087  20.365613  93.822416  67.313473  120.944829   76.730629
# 149    48.259920  16.417462  36.329137  31.842457   94.882336   28.343799
#
#       Class
# 0    Type_S
# 1    Type_S
# 2    Type_S
# 3    Type_S
# ...

# %% [markdown]
# The three datarames normal.csv,Type_H.csv and Type_S.csv are read and stored in the variables d1,d2 and d3 respectively.

# %% [markdown]
# ### B. Print Shape and columns of all the 3 DataFrames.

# %%
print("The shape of Normal.csv dataframe",d1.shape)
print("Columns in Normal.csv dataframe",list(d1.columns))
print("The shape of Type_H.csv dataframe",d2.shape)
print("Columns in Type_H.csv dataframe",list(d2.columns))
print("The shape of Type_S.csv dataframe",d3.shape)
print("Columns in Type_S.csv dataframe",list(d3.columns))
# Out:
# The shape of Normal.csv dataframe (100, 7)
# Columns in Normal.csv dataframe ['P_incidence', 'P_tilt', 'L_angle', 'S_slope', 'P_radius', 'S_Degree', 'Class']
# The shape of Type_H.csv dataframe (60, 7)
# Columns in Type_H.csv dataframe ['P_incidence', 'P_tilt', 'L_angle', 'S_slope', 'P_radius', 'S_Degree', 'Class']
# The shape of Type_S.csv dataframe (150, 7)
# Columns in Type_S.csv dataframe ['P_incidence', 'P_tilt', 'L_angle', 'S_slope', 'P_radius', 'S_Degree', 'Class']

# %% [markdown]
# ### C. Compare Column names of all the 3 DataFrames and clearly write observations

# %%
print(d1.info())
print(d2.info())
print(d3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   P_incidence  100 non-null    float64
#  1   P_tilt       100 non-null    float64
#  2   L_angle      100 non-null    float64
#  3   S_slope      100 non-null    float64
#  4   P_radius     100 non-null    float64
#  5   S_Degree     100 non-null    float64
#  6   Class        100 non-null    object
# dtypes: float64(6), object(1)
# memory usage: 5.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   P_incidence  60 non-null     float64
#  1   P_tilt       60 non-null     float64
#  2   L_angle      60 non-null     float64
#  3   S_slope      60 non-null     float64
#  4   P_radius     60 non-null     float64
# ...

# %%
if (d1.columns==d2.columns).all() and (d1.columns==d3.columns).all():
    print ("All dataframes have same coulmn name")
else:
    print ("Column names in the dataframes do not match")
# Out:
# All dataframes have same coulmn name

# %% [markdown]
# The drataframes Normal.csv,Type_H.csv and Type_S.csv contain same column name, datatype and non-null count.
# The number of rows ie. the index range of these dataframes differ as 100entries, 60 entries and 150 entries respectively.

# %% [markdown]
# ### D. Print DataTypes of all the 3 DataFrames

# %%
print("Datatype of Normal.csv is as follows: \n",d1.dtypes,"\n")
print("Datatype of Type_H.csv is as follows: \n",d2.dtypes,"\n")
print("Datatype of Type_S.csv is as follows: \n",d3.dtypes,"\n")
# Out:
# Datatype of Normal.csv is as follows:
#  P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class           object
# dtype: object
#
# Datatype of Type_H.csv is as follows:
#  P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class           object
# dtype: object
#
# Datatype of Type_S.csv is as follows:
#  P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class           object
# dtype: object

# %% [markdown]
# ### E. Observe and share variation in ‘Class’ feature of all the 3 DaraFrames.

# %%
print("The variation in 'class' feature of Normal.csv is",d1['Class'].unique())
print("The variation in 'class' feature of Type_H.csv is",d2['Class'].unique())
print("The variation in 'class' feature of Type_S.csv is",d3['Class'].unique())
# Out:
# The variation in 'class' feature of Normal.csv is ['Normal' 'Nrmal']
# The variation in 'class' feature of Type_H.csv is ['Type_H' 'type_h']
# The variation in 'class' feature of Type_S.csv is ['Type_S' 'tp_s']

# %% [markdown]
# Variation in 'Class' feature of all the 3 datarames are obsrved and shared. It is found that the dataframe NORMAL.csv has two variations 'Normal' and 'Nrmal';dataframe TYPE_H.csv has the variations 'Type_H' and 'type_h';dataframe TYPE_S.csv has variations 'Type_S' and 'tp_s'.

# %% [markdown]
# ### 2. Data Preparation and Exploration
# ### A. Unify all the variations in ‘Class’ feature for all the 3 DataFrames

# %%
d1['Class']=d1['Class'].replace(['Normal','Nrmal'],'normal')
d2['Class']=d2['Class'].replace(['Type_H','type_h'],'type_h')
d3['Class']=d3['Class'].replace(['Type_S','tp_s'],'type_s')

# %%
print("The variation in 'class' feature of NORMAL.csv is",d1['Class'].unique())
print("The variation in 'class' feature of TYPE_H.csv is",d2['Class'].unique())
print("The variation in 'class' feature of TYPE_S.csv is",d3['Class'].unique())
# Out:
# The variation in 'class' feature of NORMAL.csv is ['normal']
# The variation in 'class' feature of TYPE_H.csv is ['type_h']
# The variation in 'class' feature of TYPE_S.csv is ['type_s']

# %% [markdown]
# All the variations in 'Class' feature for all the 3 dataframes are unified.

# %% [markdown]
# ### B. Combine all the 3 DataFrames to form a single DataFrame

# %%
#df=pd.concat([normal,type_h,type_s],keys=['normal','type_h','type_s'])
df=pd.concat(([d1,d2,d3]),ignore_index=True)
df
# Out:
#      P_incidence     P_tilt    L_angle    S_slope    P_radius    S_Degree  \
# 0      38.505273  16.964297  35.112814  21.540976  127.632875    7.986683
# 1      54.920858  18.968430  51.601455  35.952428  125.846646    2.001642
# 2      44.362490   8.945435  46.902096  35.417055  129.220682    4.994195
# 3      48.318931  17.452121  48.000000  30.866809  128.980308   -0.910941
# 4      45.701789  10.659859  42.577846  35.041929  130.178314   -3.388910
# ..           ...        ...        ...        ...         ...         ...
# 305    80.111572  33.942432  85.101608  46.169139  125.593624  100.292107
# 306    95.480229  46.550053  59.000000  48.930176   96.683903   77.283072
# 307    74.094731  18.823727  76.032156  55.271004  128.405731   73.388216
# 308    87.679087  20.365613  93.822416  67.313473  120.944829   76.730629
# 309    48.259920  16.417462  36.329137  31.842457   94.882336   28.343799
#
#       Class
# 0    normal
# 1    normal
# 2    normal
# 3    normal
# ...

# %%
df.shape
# Out:
# (310, 7)

# %% [markdown]
# The dataframes Nomal.csv,Type_H.csv and Type_S.csv are all combined together into a single dataframe.
# The shape of the resultant dataframe df is (310,7)

# %% [markdown]
# ### C. Print 5 random samples of this DataFrame

# %%
print("The 5 random sample of the df Dataframe is \n",df.sample(n=5))
# Out:
# The 5 random sample of the df Dataframe is
#       P_incidence     P_tilt    L_angle    S_slope    P_radius   S_Degree  \
# 277    80.817771  19.238981  61.642451  61.578791   89.471834  44.167602
# 238    72.054034  24.700737  79.874016  47.353297  107.172358  56.426159
# 219    60.753893  15.753894  43.199158  45.000000  113.053331  31.693548
# 165    83.933009  41.286305  62.000000  42.646703  115.012334  26.588100
# 246    85.581710  30.457039  78.231379  55.124672  114.866049  68.376122
#
#       Class
# 277  type_s
# 238  type_s
# 219  type_s
# 165  type_s
# 246  type_s

# %% [markdown]
# ### D. Print Feature-wise percentage of Null values.

# %%
null_percentage=df.isnull().mean()*100
print(null_percentage)
# Out:
# P_incidence    0.0
# P_tilt         0.0
# L_angle        0.0
# S_slope        0.0
# P_radius       0.0
# S_Degree       0.0
# Class          0.0
# dtype: float64

# %% [markdown]
# The feature-wise percentage of Null values in the dataframe is 0 as there are no null values in the dataframe.

# %% [markdown]
# ### E. Check 5-point summary of the new DataFrame.

# %%
df.describe()
# Out:
#        P_incidence      P_tilt     L_angle     S_slope    P_radius    S_Degree
# count   310.000000  310.000000  310.000000  310.000000  310.000000  310.000000
# mean     60.496653   17.542822   51.930930   42.953831  117.920655   26.296694
# std      17.236520   10.008330   18.554064   13.423102   13.317377   37.559027
# min      26.147921   -6.554948   14.000000   13.366931   70.082575  -11.058179
# 25%      46.430294   10.667069   37.000000   33.347122  110.709196    1.603727
# 50%      58.691038   16.357689   49.562398   42.404912  118.268178   11.767934
# 75%      72.877696   22.120395   63.000000   52.695888  125.467674   41.287352
# max     129.834041   49.431864  125.742385  121.429566  163.071041  418.543082

# %% [markdown]
# The 5 point describption gives the mean, median, standard deviation, quartile values, minimum and maximum range of each feature in the dataframe.

# %% [markdown]
# ### 3. Data Analysis:
# ### A. Visualize a heatmap to understand correlation between all features

# %%
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.title('Correlation between Features')
# Out:
# Text(0.5, 1.0, 'Correlation between Features')

# %% [markdown]
# From the heatmap we can observe that the Features 'P_incidence' and 'S_slope' are highly correlated with correlation of 81% which is followed by 'P_incidence' and 'L_angle' with a coorelation of 72%.
#
# The features 'P_radius' and 'S_slope' on the other hand are the least correlated with a relation of negative 0.34 which is followed up by the correlation of 'P_incidence' and 'P_radius' with a negative correlation of 0.25

# %% [markdown]
# ### B. Share insights on correlation.
# #### A. Features having stronger correlation with correlation value.
# #### B. Features having weaker correlation with correlation value.

# %%
df.corr()
# Out:
#              P_incidence    P_tilt   L_angle   S_slope  P_radius  S_Degree
# P_incidence     1.000000  0.629199  0.717282  0.814960 -0.247467  0.638743
# P_tilt          0.629199  1.000000  0.432764  0.062345  0.032668  0.397862
# L_angle         0.717282  0.432764  1.000000  0.598387 -0.080344  0.533667
# S_slope         0.814960  0.062345  0.598387  1.000000 -0.342128  0.523557
# P_radius       -0.247467  0.032668 -0.080344 -0.342128  1.000000 -0.026065
# S_Degree        0.638743  0.397862  0.533667  0.523557 -0.026065  1.000000

# %% [markdown]
# A. Features having stronger correlation with correlation value.
#
# The Features 'P_incidence' and 'S_slope' are highly correlated with correlation value of 0.814960 which is appoximately 81%.
# Followed by the Features'P_incidence' and 'L_angle' with a coorelation value of 0.717282 which is approximatelt 72%.
#
# B. Features having weaker correlation with correlation value.
#
# The features 'P_radius' and 'S_slope' on the other hand are the least correlated with a relation of negative 0.342128 which is followed up by the correlation of 'P_incidence' and 'P_radius' with a negative correlation of 0.247467

# %% [markdown]
# ### C. Visualize a pairplot with 3 classes distinguished by colors and share insights.

# %%
sns.pairplot(data=df,vars=['P_incidence','P_tilt','L_angle','S_slope','P_radius','S_Degree'],hue='Class')

# %% [markdown]
# We can observe from the graphs that type_s has many variables than ytpe_h and normal and it is most densly populated.
#
# The green dots represent the type_s, orange represent type_h and blue represents normal.

# %% [markdown]
# ### D. Visualize a jointplot for ‘P_incidence’ and ‘S_slope’ and share insights.

# %%
sns.jointplot(x='P_incidence',y='S_slope',data=df)

# %% [markdown]
# The features P_incidence and S_slope are positively correlated to eachother with a hig density between (40,20) to (100,70)

# %% [markdown]
# ### E. Visualize a boxplot to check distribution of the features and share insights.

# %%
sns.boxplot(data=df[['P_incidence', 'P_tilt', 'L_angle', 'S_slope', 'P_radius', 'S_Degree', 'Class']])
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the boxplot we observe that there are outliers in all features of the dataframe.It is also observed that the P_incidence,L_angle,S_slope has negligible outliers beyond the upper fence/upper extreme limit.
# The features P_tilt and P_radius has outliers beyond the upper and the lower extreme limits.S_degree has outliers above the upper extreme limt and it also has global outliers that is very far away from the other values.

# %% [markdown]
# ### 4. Model Building:
# ### A. Split data into X and Y

# %%
x=df.drop(['Class'],axis=1)
y=df[['Class']]

# %% [markdown]
# The data is split into X - independent variables and Y - dependent variable(target column)

# %% [markdown]
# ### B. Split data into train and test with 80:20 proportion.

# %%
from scipy.stats import zscore
xscaled=x.apply(zscore)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(xscaled, y, test_size=0.20, random_state=1)
print("{0:0.2f}% data is in training set".format((len(x_train)/len(df.index)) * 100))
print("{0:0.2f}% data is in test set".format((len(x_test)/len(df.index)) * 100))
# Out:
# 80.00% data is in training set
# 20.00% data is in test set

# %% [markdown]
# The data is split into x_train,y_train, x_test,  y_test for Test and train set in the proportion 80:20

# %% [markdown]
# ### C. Train a Supervised Learning Classification base model using KNN classifier.

# %%
from sklearn.neighbors import KNeighborsClassifier
NNH = KNeighborsClassifier(n_neighbors= 5,weights='distance')

# %%
NNH.fit(x_train, y_train.values.ravel())
# Out:
# KNeighborsClassifier(weights='distance')

# %%
y_predict = NNH.predict(x_test)
NNH.score(x_test, y_test)
# Out:
# 0.7258064516129032

# %% [markdown]
# The test score for KNN classification model is 85.4%

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix

print("Confusion Matrix")
cm=metrics.confusion_matrix(y_test, y_predict, labels=["normal", "type_h","type_s"])
df_cm = pd.DataFrame(cm, index = [i for i in ["normal","type_h","type_s"]],
                  columns = [i for i in ["Predict normal","Predict type_h","Predict type_s"]])
plt.figure(figsize = (7,5))
sns.heatmap(df_cm, annot=True)
# Out:
# Confusion Matrix
# <AxesSubplot:>

# %%
print(confusion_matrix(y_test,y_predict))
# Out:
# [[12  2  4]
#  [ 4  7  0]
#  [ 5  2 26]]

# %% [markdown]
# ### D. Print all the possible performance metrics for both train and test data.

# %%
from sklearn.metrics import classification_report
y_train_pred = NNH.predict(x_train)
basereporttrain=classification_report(y_train,y_train_pred)
print(basereporttrain)
# Out:
#               precision    recall  f1-score   support
#
#       normal       1.00      1.00      1.00        82
#       type_h       1.00      1.00      1.00        49
#       type_s       1.00      1.00      1.00       117
#
#     accuracy                           1.00       248
#    macro avg       1.00      1.00      1.00       248
# weighted avg       1.00      1.00      1.00       248

# %%
from sklearn.metrics import classification_report
basereport=classification_report(y_test,y_predict)
print(basereport)
# Out:
#               precision    recall  f1-score   support
#
#       normal       0.57      0.67      0.62        18
#       type_h       0.64      0.64      0.64        11
#       type_s       0.87      0.79      0.83        33
#
#     accuracy                           0.73        62
#    macro avg       0.69      0.70      0.69        62
# weighted avg       0.74      0.73      0.73        62

# %% [markdown]
# The accuracy score for the KNN model is 73%. The F-Test score of the model is 62,64,83 for normal,type_h,type_s respectively.

# %% [markdown]
# ### 5. Performance Improvement:
# ### A. Experiment with various parameters to improve performance of the base model.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')
# Define a list of hyperparameters to tune
param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11], # Number of neighbors to consider
    'weights': ['uniform', 'distance'], # Weight function used in prediction
    'p': [1, 2] # Distance metric used for the algorithm
}

# Use grid search to find the best hyperparameters
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(NNH, param_grid, cv=5, verbose=1)
grid_search.fit(x_train, y_train)

# Print the best hyperparameters and their corresponding accuracy score
print("Best Hyperparameters:", grid_search.best_params_)
print("Best Accuracy Score:", grid_search.best_score_)

# Test the model using the best hyperparameters
knn = KNeighborsClassifier(n_neighbors=grid_search.best_params_['n_neighbors'], 
                           weights=grid_search.best_params_['weights'], 
                           p=grid_search.best_params_['p'])
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)

# Calculate accuracy score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy Score:", accuracy)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Hyperparameters: {'n_neighbors': 7, 'p': 2, 'weights': 'distance'}
# Best Accuracy Score: 0.810530612244898
# Accuracy Score: 0.7580645161290323

# %% [markdown]
# The accuracy score is increased from 72% to 75% and can be further improved further to the best accuracy of 81%.

# %% [markdown]
# ### B. Clearly showcase improvement in performance achieved.

# %%
from sklearn.metrics import classification_report
basereport=classification_report(y_test,y_predict)
print(basereport)
# Out:
#               precision    recall  f1-score   support
#
#       normal       0.57      0.67      0.62        18
#       type_h       0.64      0.64      0.64        11
#       type_s       0.87      0.79      0.83        33
#
#     accuracy                           0.73        62
#    macro avg       0.69      0.70      0.69        62
# weighted avg       0.74      0.73      0.73        62

# %%
from sklearn.metrics import classification_report
basereport=classification_report(y_test,y_pred)
print(basereport)
# Out:
#               precision    recall  f1-score   support
#
#       normal       0.60      0.67      0.63        18
#       type_h       0.75      0.82      0.78        11
#       type_s       0.87      0.79      0.83        33
#
#     accuracy                           0.76        62
#    macro avg       0.74      0.76      0.75        62
# weighted avg       0.77      0.76      0.76        62

# %% [markdown]
# The accuracy score is increased from 72% to 75%.
#
# The f-score is increased from 0.62 to 0.63.
#
# The precision,recall values are also comparetively increased.

# %% [markdown]
# ### C. Clearly state which parameters contributed most to improve model performance.

# %% [markdown]
# From the above codes we can say that the best parameters contributed are:
#
# 'n_neighbors': 7, 'p': 2, 'weights': 'distance'

# %% [markdown]
# # PART B

# %% [markdown]
# ### 1. Data Understanding and Preparation:
# ### A. Read both the Datasets ‘Data1’ and ‘Data 2’ as DataFrame and store them into two separate variables

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data1=pd.read_csv("Downloads\Data1.csv")
data2=pd.read_csv("Downloads\Data2.csv")

# %%
data1
# Out:
#         ID  Age  CustomerSince  HighestSpend  ZipCode  HiddenScore  \
# 0        1   25              1            49    91107            4
# 1        2   45             19            34    90089            3
# 2        3   39             15            11    94720            1
# 3        4   35              9           100    94112            1
# 4        5   35              8            45    91330            4
# ...    ...  ...            ...           ...      ...          ...
# 4995  4996   29              3            40    92697            1
# 4996  4997   30              4            15    92037            4
# 4997  4998   63             39            24    93023            2
# 4998  4999   65             40            49    90034            3
# 4999  5000   28              4            83    92612            3
#
#       MonthlyAverageSpend  Level
# 0                     1.6      1
# 1                     1.5      1
# 2                     1.0      1
# ...

# %%
data2
# Out:
#         ID  Mortgage  Security  FixedDepositAccount  InternetBanking  \
# 0        1         0         1                    0                0
# 1        2         0         1                    0                0
# 2        3         0         0                    0                0
# 3        4         0         0                    0                0
# 4        5         0         0                    0                0
# ...    ...       ...       ...                  ...              ...
# 4995  4996         0         0                    0                1
# 4996  4997        85         0                    0                1
# 4997  4998         0         0                    0                0
# 4998  4999         0         0                    0                1
# 4999  5000         0         0                    0                1
#
#       CreditCard  LoanOnCard
# 0              0         NaN
# 1              0         NaN
# 2              0         NaN
# ...

# %% [markdown]
# The datadrames Data1 and Data2 are read using pandas and are stored in the variables data1 and data2 respectively

# %% [markdown]
# ### B. Print shape and Column Names and DataTypes of both the Dataframes.

# %%
print("For Data1.csv Dataframe:")
print("Shape=",data1.shape,"\nColumn names=",list(data1.columns),"\nDataType:\n",data1.dtypes)
# Out:
# For Data1.csv Dataframe:
# Shape= (5000, 8)
# Column names= ['ID', 'Age', 'CustomerSince', 'HighestSpend', 'ZipCode', 'HiddenScore', 'MonthlyAverageSpend', 'Level']
# DataType:
#  ID                       int64
# Age                      int64
# CustomerSince            int64
# HighestSpend             int64
# ZipCode                  int64
# HiddenScore              int64
# MonthlyAverageSpend    float64
# Level                    int64
# dtype: object

# %%
print("For Data2.csv Dataframe:")
print("Shape=",data2.shape,"\nColumn names=",list(data2.columns),"\nDataType:\n",data2.dtypes)
# Out:
# For Data2.csv Dataframe:
# Shape= (5000, 7)
# Column names= ['ID', 'Mortgage', 'Security', 'FixedDepositAccount', 'InternetBanking', 'CreditCard', 'LoanOnCard']
# DataType:
#  ID                       int64
# Mortgage                 int64
# Security                 int64
# FixedDepositAccount      int64
# InternetBanking          int64
# CreditCard               int64
# LoanOnCard             float64
# dtype: object

# %% [markdown]
# The dataframes shape,column names and datatypes are printed

# %% [markdown]
# ### C. Merge both the Dataframes on ‘ID’ feature to form a single DataFrame

# %%
mdf=pd.merge(data1,data2,on='ID')
mdf
# Out:
#         ID  Age  CustomerSince  HighestSpend  ZipCode  HiddenScore  \
# 0        1   25              1            49    91107            4
# 1        2   45             19            34    90089            3
# 2        3   39             15            11    94720            1
# 3        4   35              9           100    94112            1
# 4        5   35              8            45    91330            4
# ...    ...  ...            ...           ...      ...          ...
# 4995  4996   29              3            40    92697            1
# 4996  4997   30              4            15    92037            4
# 4997  4998   63             39            24    93023            2
# 4998  4999   65             40            49    90034            3
# 4999  5000   28              4            83    92612            3
#
#       MonthlyAverageSpend  Level  Mortgage  Security  FixedDepositAccount  \
# 0                     1.6      1         0         1                    0
# ...

# %% [markdown]
# ### D. Change Datatype of below features to ‘Object’
# ### ‘CreditCard’, ‘InternetBanking’, ‘FixedDepositAccount’, ‘Security’, ‘Level’, ‘HiddenScore’

# %%
mdf['CreditCard']=mdf['CreditCard'].astype(object)
mdf['InternetBanking']=mdf['InternetBanking'].astype(object)
mdf['FixedDepositAccount']=mdf['FixedDepositAccount'].astype(object)
mdf['Security']=mdf['Security'].astype(object)
mdf['Level']=mdf['Level'].astype(object)
mdf['HiddenScore']=mdf['HiddenScore'].astype(object)

# %%
mdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   5000 non-null   int64
#  1   Age                  5000 non-null   int64
#  2   CustomerSince        5000 non-null   int64
#  3   HighestSpend         5000 non-null   int64
#  4   ZipCode              5000 non-null   int64
#  5   HiddenScore          5000 non-null   object
#  6   MonthlyAverageSpend  5000 non-null   float64
#  7   Level                5000 non-null   object
#  8   Mortgage             5000 non-null   int64
#  9   Security             5000 non-null   object
#  10  FixedDepositAccount  5000 non-null   object
#  11  InternetBanking      5000 non-null   object
#  12  CreditCard           5000 non-null   object
#  13  LoanOnCard           4980 non-null   float64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 585.9+ KB

# %% [markdown]
# The datatypes of the features ‘CreditCard’, ‘InternetBanking’, ‘FixedDepositAccount’, ‘Security’, ‘Level’, ‘HiddenScore’ are converted to OBJECT datatype

# %% [markdown]
# ### 2. Data Exploration and Analysis:
# ### A. Visualize distribution of Target variable ‘LoanOnCard’ and clearly share insights.

# %%
mdf['LoanOnCard']=mdf['LoanOnCard'].astype('category')
sns.histplot(mdf['LoanOnCard'])
plt.title("Distribution of LoanOnCard")
plt.xlabel("LoanOnCard")
plt.ylabel("Count/Frequency")
# Out:
# Text(0, 0.5, 'Count/Frequency')

# %% [markdown]
# The Target variable column is biased with an approximate proportion of 90:10

# %% [markdown]
# ### B. Check the percentage of missing values and impute if required.

# %%
missing_percentage=mdf['LoanOnCard'].isnull().mean()*100
missing_percentage
# Out:
# 0.4

# %%
#mdf['LoanOnCard']=mdf['LoanOnCard'].astype('float')
#mdf['LoanOnCard'].fillna(mdf['LoanOnCard'].mean(),inplace=True)
mdf=mdf.dropna(subset=['LoanOnCard'])
mdf
# Out:
#         ID  Age  CustomerSince  HighestSpend  ZipCode HiddenScore  \
# 9       10   34              9           180    93023           1
# 10      11   65             39           105    94710           4
# 11      12   29              5            45    90277           3
# 12      13   48             23           114    93106           2
# 13      14   59             32            40    94920           4
# ...    ...  ...            ...           ...      ...         ...
# 4995  4996   29              3            40    92697           1
# 4996  4997   30              4            15    92037           4
# 4997  4998   63             39            24    93023           2
# 4998  4999   65             40            49    90034           3
# 4999  5000   28              4            83    92612           3
#
#       MonthlyAverageSpend Level  Mortgage Security FixedDepositAccount  \
# 9                     8.9     3         0        0                   0
# ...

# %% [markdown]
# The percentage of missing values in 'LoanOnCard' feature is 0.4 (ie.40%).
#
# Since there are missing values, we remove the rows with missing values.The shape of the dataframe is (4980,14)

# %% [markdown]
# ### C. Check for unexpected values in each categorical variable and impute with best suitable value.

# %%
mdf.dtypes
# Out:
# ID                        int64
# Age                       int64
# CustomerSince             int64
# HighestSpend              int64
# ZipCode                   int64
# HiddenScore              object
# MonthlyAverageSpend     float64
# Level                    object
# Mortgage                  int64
# Security                 object
# FixedDepositAccount      object
# InternetBanking          object
# CreditCard               object
# LoanOnCard             category
# dtype: object

# %%
print(mdf['HiddenScore'].unique())
print(mdf['Level'].unique())
print(mdf['Security'].unique())
print(mdf['FixedDepositAccount'].unique())
print(mdf['InternetBanking'].unique())
print(mdf['CreditCard'].unique())
# Out:
# [1 4 3 2]
# [3 2 1]
# [0 1]
# [0 1]
# [0 1]
# [0 1]

# %%
print(mdf['LoanOnCard'].unique())
# Out:
# [1.0, 0.0]
# Categories (2, float64): [0.0, 1.0]

# %% [markdown]
# As we can see, there are no unexpected values in each categorical variable and hence no need to impute.

# %% [markdown]
# ### 3. Data Preparation and model building:
# ### A. Split data into X and Y.

# %%
X = mdf.drop(['ID','ZipCode','LoanOnCard'],axis=1)
Y = mdf[['LoanOnCard']]

# %%
X
# Out:
#       Age  CustomerSince  HighestSpend HiddenScore  MonthlyAverageSpend Level  \
# 9      34              9           180           1                  8.9     3
# 10     65             39           105           4                  2.4     3
# 11     29              5            45           3                  0.1     2
# 12     48             23           114           2                  3.8     3
# 13     59             32            40           4                  2.5     2
# ...   ...            ...           ...         ...                  ...   ...
# 4995   29              3            40           1                  1.9     3
# 4996   30              4            15           4                  0.4     1
# 4997   63             39            24           2                  0.3     3
# 4998   65             40            49           3                  0.5     2
# 4999   28              4            83           3                  0.8     1
#
# ...

# %%
Y
# Out:
#      LoanOnCard
# 9           1.0
# 10          0.0
# 11          0.0
# 12          0.0
# 13          0.0
# ...         ...
# 4995        0.0
# 4996        0.0
# 4997        0.0
# 4998        0.0
# 4999        0.0
#
# [4980 rows x 1 columns]

# %% [markdown]
# ### B. Split data into train and test. Keep 25% data reserved for testing.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=1)

# %%
print("{0:0.2f}% data is in training set".format((len(X_train)/len(mdf.index)) * 100))
print("{0:0.2f}% data is in test set".format((len(X_test)/len(mdf.index)) * 100))
# Out:
# 75.00% data is in training set
# 25.00% data is in test set

# %% [markdown]
# ### C. Train a Supervised Learning Classification base model - Logistic Regression.

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(max_iter=5000,solver='liblinear')
logreg.fit(X_train, Y_train.values.ravel())
# Out:
# LogisticRegression(max_iter=5000, solver='liblinear')

# %%
pred_test = logreg.predict(X_test)
pred_test
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
Y_train_prob=logreg.predict_proba(X_train)[:,1]
Y_train_pred=logreg.predict(X_train)
Y_test_prob= logreg.predict_proba(X_test)[:,1]
Y_test_pred=logreg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
test_accuracy=accuracy_score(Y_test, pred_test)
# Checking accuracy
print('Test Accuracy Score: ',np.round(test_accuracy,2))
train_accuracy=accuracy_score(Y_train, Y_train_pred)
print('Train Accuracy Score: ',np.round(train_accuracy,2))
# Out:
# Test Accuracy Score:  0.95
# Train Accuracy Score:  0.95

# %%
from sklearn.metrics import classification_report,confusion_matrix
mat_train = confusion_matrix(Y_train,Y_train_pred)
print("confusion matrix_train_data = \n",mat_train)
mat_test = confusion_matrix(Y_test,pred_test)
print("confusion matrix_test_data = \n",mat_test)
# Out:
# confusion matrix_train_data =
#  [[3336   46]
#  [ 138  215]]
# confusion matrix_test_data =
#  [[1105   13]
#  [  52   75]]

# %%
#AUC ROC curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

logit_roc_auc = roc_auc_score(Y_test, logreg.predict_proba(X_test)[:,1])
fpr, tpr, thresholds = roc_curve(Y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--',label='No Skill')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %%
#AUC ROC curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
# roc curve for logistic regression model with optimal threshold
from numpy import sqrt
from numpy import argmax
logit_roc_auc = roc_auc_score(Y_test, logreg.predict_proba(X_test)[:,1])
fpr, tpr, thresholds = roc_curve(Y_test, logreg.predict_proba(X_test)[:,1])
# calculate the g-mean for each threshold
gmeans = sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = argmax(gmeans)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds[ix], gmeans[ix]))
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--',label='No Skill')
plt.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
# Out:
# Best Threshold=0.101418, G-Mean=0.899

# %%
from sklearn.metrics import precision_recall_curve
yhat=logreg.predict_proba(X_test)[:,1]
#ROC CURVE
precision, recall, thresholds = precision_recall_curve(Y_test, yhat)
fscore = (2 * precision * recall) / (precision + recall)
ix = argmax(fscore)
print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
# plot the roc curve for the model
# no_skill = len(y_test[y_test==1]) / len(y_test)
# plt.plot([0,1], [no_skill,no_skill], linestyle='--', label='No Skill')
plt.plot(recall, precision, marker='.', label='Logistic')
plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best')
# axis labels
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend()
# show the plot
plt.show()
# Out:
# Best Threshold=0.419851, F-Score=0.724

# %%
print(classification_report(Y_train,Y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.97      3382
#          1.0       0.82      0.61      0.70       353
#
#     accuracy                           0.95      3735
#    macro avg       0.89      0.80      0.84      3735
# weighted avg       0.95      0.95      0.95      3735

# %%
print(classification_report(Y_test,Y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.97      1118
#          1.0       0.85      0.59      0.70       127
#
#     accuracy                           0.95      1245
#    macro avg       0.90      0.79      0.83      1245
# weighted avg       0.94      0.95      0.94      1245

# %% [markdown]
# ### D. Print evaluation metrics for the model and clearly share insights.

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, recall_score
# Checking accuracy
print(accuracy_score(Y_test, pred_test))
# Out:
# 0.9477911646586346

# %%
# Checking unique values
predictions = pd.DataFrame(pred_test)
predictions[0].value_counts()
# Out:
# 0.0    1157
# 1.0      88
# Name: 0, dtype: int64

# %%
# confusion matrix
pd.DataFrame(confusion_matrix(Y_test, pred_test))
# Out:
#       0   1
# 0  1105  13
# 1    52  75

# %%
recall_score(Y_test, pred_test)
# Out:
# 0.5905511811023622

# %%
print(classification_report(Y_train,Y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.97      3382
#          1.0       0.82      0.61      0.70       353
#
#     accuracy                           0.95      3735
#    macro avg       0.89      0.80      0.84      3735
# weighted avg       0.95      0.95      0.95      3735

# %%
print(classification_report(Y_test,Y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.97      1118
#          1.0       0.85      0.59      0.70       127
#
#     accuracy                           0.95      1245
#    macro avg       0.90      0.79      0.83      1245
# weighted avg       0.94      0.95      0.94      1245

# %% [markdown]
# The precision value of the test and train sets are

# %% [markdown]
# ### E. Balance the data using the right balancing technique. [2 Marks]
# ### i. Check distribution of the target variable
# ### ii. Say output is class A : 20% and class B : 80%
# ### iii. Here you need to balance the target variable as 50:50.
# ### iv. Try appropriate method to achieve the same.

# %%
#checking distribution of the target variable
dist=mdf['LoanOnCard'].value_counts(normalize=True)*100
print(dist)
# Out:
# 0.0    90.361446
# 1.0     9.638554
# Name: LoanOnCard, dtype: float64

# %%
from sklearn.utils import resample
majority_class = mdf[mdf['LoanOnCard'] == 0]
minority_class = mdf[mdf['LoanOnCard'] == 1]

# Downsample the majority class to match the minority class
majority_downsampled = resample(majority_class, replace=False, n_samples=len(minority_class))

# Combine the minority class and downsampled majority class
balanced_df = pd.concat([majority_downsampled, minority_class])

# Check the distribution of the target variable in the balanced dataframe
target_dist = balanced_df['LoanOnCard'].value_counts(normalize=True) * 100
print(target_dist)
# Out:
# 0.0    50.0
# 1.0    50.0
# Name: LoanOnCard, dtype: float64

# %% [markdown]
# the resample() function from Scikit-learn to downsample the majority class to match the minority class. The replace=False parameter ensures that sampling is done without replacement. The n_samples parameter is set to the length of the minority class.
#
# Finally, you combine the minority class and downsampled majority class using the pd.concat() function, and save the result in balanced_df.

# %% [markdown]
# ### F. Again train the same previous model on balanced data.

# %%
X1 = balanced_df.drop(['ID','ZipCode','LoanOnCard'],axis=1)
Y1 = balanced_df[['LoanOnCard']]
X1_train, X1_test, Y1_train, Y1_test = train_test_split(X1, Y1, test_size=0.25, random_state=1)

logreg1 = LogisticRegression(max_iter=5000,solver='liblinear')
logreg1.fit(X1_train, Y1_train.values.ravel())

pred_test1 = logreg1.predict(X1_test)
pred_test1

pred_train1 = logreg1.predict(X1_train)

Y1_train_prob=logreg1.predict_proba(X1_train)[:,1]
Y1_train_pred=logreg1.predict(X1_train)
Y1_test_prob= logreg1.predict_proba(X1_test)[:,1]
Y1_test_pred=logreg1.predict(X1_test)

# %%
X1
# Out:
#       Age  CustomerSince  HighestSpend HiddenScore  MonthlyAverageSpend Level  \
# 2645   36             12            93           2                  2.2     1
# 1761   52             27            45           2                  2.0     2
# 1965   45             20            94           3                  0.5     3
# 3809   26              2            62           4                  1.6     1
# 3671   50             25            18           1                  0.4     3
# ...   ...            ...           ...         ...                  ...   ...
# 4883   38             13           129           3                  4.1     3
# 4927   43             19           121           1                  0.7     2
# 4941   28              4           112           2                  1.6     2
# 4962   46             20           122           3                  3.0     3
# 4980   29              5           135           3                  5.3     1
#
# ...

# %%
test_accuracy1=accuracy_score(Y1_test, pred_test1)
# Checking accuracy
print('Test Accuracy Score: ',np.round(test_accuracy1,2))
train_accuracy1=accuracy_score(Y1_train, pred_train1)
print('Test Accuracy: ',np.round(train_accuracy1,2))
mat_train1 = confusion_matrix(Y1_train,pred_train1)
print("confusion matrix_train_data = \n",mat_train1)
mat_test1 = confusion_matrix(Y1_test,pred_test1)
print("confusion matrix_test_data = \n",mat_test1)
# Out:
# Test Accuracy Score:  0.88
# Test Accuracy:  0.9
# confusion matrix_train_data =
#  [[331  32]
#  [ 39 318]]
# confusion matrix_test_data =
#  [[100  17]
#  [ 12 111]]

# %% [markdown]
# ### G. Print evaluation metrics and clearly share differences observed.

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, recall_score
# Checking accuracy
print("Accuracy Score",accuracy_score(Y1_test, pred_test1))
# Checking unique values
predictions1 = pd.DataFrame(pred_test1)
print("Predictions\n",predictions1[0].value_counts())
# confusion matrix
print("Confusion Matrix\n",pd.DataFrame(confusion_matrix(Y1_test, pred_test1)))
#recall score
print("Recall Score",recall_score(Y1_test, pred_test1))
# Out:
# Accuracy Score 0.8791666666666667
# Predictions
#  1.0    128
# 0.0    112
# Name: 0, dtype: int64
# Confusion Matrix
#       0    1
# 0  100   17
# 1   12  111
# Recall Score 0.9024390243902439

# %%
from sklearn.metrics import precision_recall_curve
yhat1=logreg1.predict_proba(X1_test)[:,1]
#ROC CURVE
precision, recall, thresholds = precision_recall_curve(Y1_test, yhat1)
fscore1 = (2 * precision * recall) / (precision+ recall)
ix1 = argmax(fscore1)
print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix1], fscore1[ix1]))
# plot the roc curve for the model
# no_skill = len(y_test[y_test==1]) / len(y_test)
# plt.plot([0,1], [no_skill,no_skill], linestyle='--', label='No Skill')
plt.plot(recall, precision, marker='.', label='Logistic')
plt.scatter(recall[ix1], precision[ix1], marker='o', color='black', label='Best')
# axis labels
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend()
# show the plot
plt.show()
# Out:
# Best Threshold=0.533892, F-Score=0.884

# %%
print(classification_report(Y1_train,Y1_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.91      0.90       363
#          1.0       0.91      0.89      0.90       357
#
#     accuracy                           0.90       720
#    macro avg       0.90      0.90      0.90       720
# weighted avg       0.90      0.90      0.90       720

# %%
print(classification_report(Y1_test,Y1_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.85      0.87       117
#          1.0       0.87      0.90      0.88       123
#
#     accuracy                           0.88       240
#    macro avg       0.88      0.88      0.88       240
# weighted avg       0.88      0.88      0.88       240

# %% [markdown]
# The total rows is reduced from 4980 to 60 rows since we used undersampling to balance the target variables.
#
# The Accuracy score is reduced from 95% to 89% after balancing.
#
# The recall Score is increased from 59% to 88% after balancing.
#
# The f-score value is increaed from 74% to 92% after balancing.
#
# The Threshold is decreased from 46% to 38% after balancing.
#
# The precision is decreased to 89%.

# %% [markdown]
# ### 4. Performance Improvement:
# ### A. Train a base model each for SVM, KNN.

# %%
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
# Train SVM model
svm_model = svm.SVC(kernel='linear')
svm_model.fit(X_train, Y_train.values.ravel())

# Predict using SVM model
Y_pred_svm = svm_model.predict(X_test)

# %%
# Calculate accuracy score for SVM model
acc_svm = accuracy_score(Y_test, Y_pred_svm)
print('SVM Accuracy:', acc_svm)

# Train KNN model
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train, Y_train.values.ravel())

# Predict using KNN model
Y_pred_knn = knn_model.predict(X_test)

# Calculate accuracy score for KNN model
acc_knn = accuracy_score(Y_test, Y_pred_knn)
print('KNN Accuracy:', acc_knn)
# Out:
# SVM Accuracy: 0.9502008032128514
# KNN Accuracy: 0.9012048192771084

# %%
print(classification_report(Y_test,Y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.99      0.97      1118
#          1.0       0.89      0.58      0.70       127
#
#     accuracy                           0.95      1245
#    macro avg       0.92      0.79      0.84      1245
# weighted avg       0.95      0.95      0.95      1245

# %%
print(classification_report(Y_test,Y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.97      0.95      1118
#          1.0       0.53      0.31      0.39       127
#
#     accuracy                           0.90      1245
#    macro avg       0.73      0.64      0.67      1245
# weighted avg       0.88      0.90      0.89      1245

# %%
Y_train_pred_svm = svm_model.predict(X_train)
print(classification_report(Y_train,Y_train_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.97      3382
#          1.0       0.88      0.59      0.71       353
#
#     accuracy                           0.95      3735
#    macro avg       0.92      0.79      0.84      3735
# weighted avg       0.95      0.95      0.95      3735

# %%
Y_train_pred_knn=knn_model.predict(X_train)
print(classification_report(Y_train,Y_train_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.98      0.97      3382
#          1.0       0.76      0.52      0.62       353
#
#     accuracy                           0.94      3735
#    macro avg       0.86      0.75      0.79      3735
# weighted avg       0.93      0.94      0.93      3735

# %% [markdown]
# The precision,recall,f1-score and Accuracy score of SVM is better than that of KNN model and hence we proceed with SVM model for our final model

# %% [markdown]
# ### B. Tune parameters for each of the models wherever required and finalize a model.
# ### (Optional: Experiment with various Hyperparameters - Research required)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# Set up KNN model
knn = KNeighborsClassifier()

# Set up SVM model
svm = SVC()

# %%
knn_param_grid = {'n_neighbors': [3, 5, 7, 9]}
svm_param_grid = {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf']}

# Set up grid search
knn_grid_search = GridSearchCV(knn, knn_param_grid, cv=5)
svm_grid_search = GridSearchCV(svm, svm_param_grid, cv=5)

# %%
# Fit the grid search to the data
knn_grid_search.fit(X_train, Y_train)
svm_grid_search.fit(X_train, Y_train)

# Print the best parameters and accuracy scores for KNN and SVM models
print('Best parameters for KNN:', knn_grid_search.best_params_)
print('Best accuracy score for KNN:', knn_grid_search.best_score_)
print('Best parameters for SVM:', svm_grid_search.best_params_)
print('Best accuracy score for SVM:', svm_grid_search.best_score_)
# Out:
# Best parameters for KNN: {'n_neighbors': 3}
# Best accuracy score for KNN: 0.9156626506024097
# Best parameters for SVM: {'C': 10, 'kernel': 'linear'}
# Best accuracy score for SVM: 0.9542168674698794

# %%
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
# Train SVM model
svm_model = svm.SVC(C=10,kernel='linear')
svm_model.fit(X_train, Y_train.values.ravel())

# Predict using SVM model
Y_pred_svm = svm_model.predict(X_test)

# %%
# Calculate accuracy score for SVM model
acc_svm = accuracy_score(Y_test, Y_pred_svm)
print('SVM Accuracy:', acc_svm)

# Train KNN model
knn_model = KNeighborsClassifier(n_neighbors=3)
knn_model.fit(X_train, Y_train.values.ravel())

# Predict using KNN model
Y_pred_knn = knn_model.predict(X_test)

# Calculate accuracy score for KNN model
acc_knn = accuracy_score(Y_test, Y_pred_knn)
print('KNN Accuracy:', acc_knn)
# Out:
# SVM Accuracy: 0.9518072289156626
# KNN Accuracy: 0.8987951807228916

# %% [markdown]
# From the above we can say that the SVM model gives the best accuracy score even after tuning and hence we choose SVM model as our final model

# %% [markdown]
# ### C. Print evaluation metrics for final model.

# %%
Y_train_pred_svm = svm_model.predict(X_train)
print(classification_report(Y_train,Y_train_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.97      3382
#          1.0       0.85      0.61      0.71       353
#
#     accuracy                           0.95      3735
#    macro avg       0.91      0.80      0.84      3735
# weighted avg       0.95      0.95      0.95      3735

# %%
print(classification_report(Y_test,Y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.97      1118
#          1.0       0.87      0.62      0.72       127
#
#     accuracy                           0.95      1245
#    macro avg       0.91      0.81      0.85      1245
# weighted avg       0.95      0.95      0.95      1245

# %% [markdown]
# ### D. Share improvement achieved from base model to final model.

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import roc_curve, roc_auc_score
# Train an SVM classifier on the training data
svm_clf = SVC(probability=True, random_state=1)
svm_clf.fit(X_train, Y_train)

# Predict probabilities of class 1 on the test set
Y_prob = svm_clf.predict_proba(X_test)[:, 1]

# Calculate ROC AUC score
roc_auc = roc_auc_score(Y_test, Y_prob)

# Calculate false positive rate and true positive rate for ROC curve
fpr, tpr, thresholds = roc_curve(Y_test, Y_prob)

# Plot ROC curve
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve for SVM')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import roc_curve, roc_auc_score
# Train an SVM classifier on the training data
svm_clf = SVC(probability=True, random_state=1)
svm_clf.fit(X_train, Y_train)

# Predict probabilities of class 1 on the test set
Y_prob = svm_clf.predict_proba(X_test)[:, 1]

# Calculate ROC AUC score
roc_auc = roc_auc_score(Y_test, Y_pred_svm)

# Calculate false positive rate and true positive rate for ROC curve
fpr, tpr, thresholds = roc_curve(Y_test, Y_pred_svm)

# Plot ROC curve
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve for SVM')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# There are slight improvements in the macro avg score, precision score, recall value, f1 score of the test and train set.
# The roc_auc curve before and after tuning has a drasrtic change.
